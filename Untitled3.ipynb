# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-197e19f3-af26-49b5-af75-5953210e9851" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-197e19f3-af26-49b5-af75-5953210e9851">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('cargill_sales.csv')
df.head()
# Out:
#          Date Region     Product Category  Quantity        Sales      Profit  \
# 0  2023-01-01  South  Canola Oil     Oils       310  2759.348368  371.593246
# 1  2023-01-02   East       Wheat   Grains        99   339.970445   22.748468
# 2  2023-01-03  North  Canola Oil     Oils       112   940.803120  161.224858
# 3  2023-01-04  South        Beef     Meat       485  3114.503454  704.483866
# 4  2023-01-05  South     Chicken     Meat       259  1339.659229  303.543958
#
#   Customer Name
# 0   Customer 20
# 1   Customer 20
# 2   Customer 18
# 3   Customer 14
# 4   Customer 18

# %%
df.describe()
# Out:
#          Quantity        Sales       Profit
# count  500.000000   500.000000   500.000000
# mean   257.490000  1529.635824   229.883581
# std    142.125202  1060.998847   197.672335
# min     10.000000    45.630971     4.570894
# 25%    134.000000   636.148416    76.814238
# 50%    259.000000  1301.824475   159.678899
# 75%    384.000000  2287.194731   339.095517
# max    498.000000  4782.020820  1013.988974

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           500 non-null    object
#  1   Region         500 non-null    object
#  2   Product        500 non-null    object
#  3   Category       500 non-null    object
#  4   Quantity       500 non-null    int64
#  5   Sales          500 non-null    float64
#  6   Profit         500 non-null    float64
#  7   Customer Name  500 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 31.4+ KB

# %%
df.isnull().sum()
# Out:
# Date             0
# Region           0
# Product          0
# Category         0
# Quantity         0
# Sales            0
# Profit           0
# Customer Name    0
# dtype: int64

# %%
df.nunique()
# Out:
# Date             500
# Region             4
# Product            6
# Category           3
# Quantity         323
# Sales            500
# Profit           500
# Customer Name     20
# dtype: int64

# %%
## Q1: What are the top 5 best-selling products?
top_products = df.groupby("Product")["Sales"].sum().sort_values(ascending=False).head(5)
top_products.plot(kind='bar', title='Top 5 Products by Sales', ylabel='Total Sales', xlabel='Product', figsize=(8,4), color='skyblue')
plt.grid(True)
plt.show()

# %%
## Q2: Which region generates the highest total revenue?
region_sales = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
region_sales.plot(kind='bar', title='Sales by Region', ylabel='Total Sales', xlabel='Region', color='lightgreen')
plt.show()

# %%
## Q3: What is the monthly sales trend?
df['Month'] = pd.to_datetime(df['Date']).dt.to_period('M')
monthly_sales = df.groupby("Month")["Sales"].sum()
monthly_sales.plot(kind='line', marker='o', title='Monthly Sales Trend', ylabel='Sales', xlabel='Month', figsize=(10,5))
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
## Q4: Are there any seasonal sales patterns?
df['Month_Num'] = pd.to_datetime(df['Date']).dt.month
seasonal = df.groupby("Month_Num")["Sales"].mean()
seasonal.plot(kind='bar', title='Average Sales per Month', ylabel='Average Sales', xlabel='Month', color='orange')
plt.show()

# %%
## Q5: How does product category affect profit?
category_profit = df.groupby("Category")["Profit"].sum()
category_profit.plot(kind='bar', title='Profit by Category', ylabel='Total Profit', xlabel='Category', color='lightcoral')
plt.show()

# %%
## Q6: Who are the top 5 customers by revenue?
top_customers = df.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False).head(5)
top_customers.plot(kind='bar', title='Top 5 Customers by Sales', ylabel='Total Sales', xlabel='Customer', color='teal')
plt.show()

# %%
## Q7: Which products have the lowest profit margin?
df['Profit Margin'] = df['Profit'] / df['Sales']
low_margin = df.groupby("Product")["Profit Margin"].mean().sort_values().head(5)
low_margin.plot(kind='bar', title='Lowest Profit Margin Products', ylabel='Avg Profit Margin', xlabel='Product', color='salmon')
plt.show()

# %%
## Q8: How is quantity distributed across regions?
sns.boxplot(data=df, x="Region", y="Quantity", palette="Set2")
plt.title("Quantity Distribution by Region")
plt.show()
# Out:
# /tmp/ipython-input-15-2763598200.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Region", y="Quantity", palette="Set2")

# %%
## Q9: Is there a correlation between quantity and sales?
sns.scatterplot(data=df, x="Quantity", y="Sales", hue="Category")
plt.title("Sales vs Quantity")
plt.show()

# %%
## Q10: What is the distribution of profit?
sns.histplot(df['Profit'], bins=30, kde=True, color='purple')
plt.title("Distribution of Profit")
plt.xlabel("Profit")
plt.ylabel("Count")
plt.show()
